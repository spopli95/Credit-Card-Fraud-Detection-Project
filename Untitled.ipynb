# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('UCI_Credit_Card.csv')
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
(df["MARRIAGE"] == 3).sum()
# Out:
# 323

# %%
# Drop ID
df = df.drop(["ID"],axis = 1)
print("Data Size:",df.shape)
m = df.shape[0]
p = df.shape[1]
print(f"We have {m} instance and {p-1} features")
print(df.columns)
df.head()
# Out:
# Data Size: (30000, 24)
# We have 30000 instance and 23 features
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    20000.0    2          2         1   24      2      2     -1     -1
# 1   120000.0    2          2         2   26     -1      2      0      0
# 2    90000.0    2          2         2   34      0      0      0      0
# 3    50000.0    2          2         1   37      0      0      0      0
# 4    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...

# %%
df.rename(columns={'default.payment.next.month': 'def_pay'}, inplace=True)
df['def_pay'].hist()
plt.xlabel('Default Payment of Users')
plt.ylabel('Total Count') 
plt.savefig('classimbalance.png')
# Checking for Class imbalance

# %% [markdown]
# # Numerical Attributes

# %%
#sns.distplot(df, kde = False)
#sns.catplot(x="SEX", y="PAY_AMT6", hue="default.payment.next.month",
            #kind="swarm", data=df);

sns.pairplot(df[['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5', 'BILL_AMT6', 'def_pay']],diag_kind = 'kde',plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})
display(df[['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5', 'BILL_AMT6', 'def_pay']].corr())
#df.corr()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-957cc4667f6d> in <module>
#       3             #kind="swarm", data=df);
#       4
# ----> 5 sns.pairplot(df[['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5', 'BILL_AMT6', 'def_pay']],diag_kind = 'kde',plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})
#       6 display(df[['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5', 'BILL_AMT6', 'def_pay']].corr())
#       7 #df.corr()
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
# ...

# %%
sns.pairplot(df[['PAY_AMT1' , 'PAY_AMT2', 'PAY_AMT3' , 'PAY_AMT4', 'PAY_AMT5' , 'PAY_AMT6', 'def_pay']],diag_kind = 'kde',plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})
display(df[['PAY_AMT1' , 'PAY_AMT2', 'PAY_AMT3' , 'PAY_AMT4', 'PAY_AMT5' , 'PAY_AMT6', 'def_pay']].corr())
# Out:
#           PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6   def_pay
# PAY_AMT1  1.000000  0.285576  0.252191  0.199558  0.148459  0.185735 -0.072929
# PAY_AMT2  0.285576  1.000000  0.244770  0.180107  0.180908  0.157634 -0.058579
# PAY_AMT3  0.252191  0.244770  1.000000  0.216325  0.159214  0.162740 -0.056250
# PAY_AMT4  0.199558  0.180107  0.216325  1.000000  0.151830  0.157834 -0.056827
# PAY_AMT5  0.148459  0.180908  0.159214  0.151830  1.000000  0.154896 -0.055124
# PAY_AMT6  0.185735  0.157634  0.162740  0.157834  0.154896  1.000000 -0.053183
# def_pay  -0.072929 -0.058579 -0.056250 -0.056827 -0.055124 -0.053183  1.000000

# %%
display(df[['PAY_0' , 'PAY_2', 'PAY_3' , 'PAY_4', 'PAY_5' , 'PAY_6', 'def_pay']].corr())
# Out:
#             PAY_0     PAY_2     PAY_3     PAY_4     PAY_5     PAY_6   def_pay
# PAY_0    1.000000  0.672164  0.574245  0.538841  0.509426  0.474553  0.324794
# PAY_2    0.672164  1.000000  0.766552  0.662067  0.622780  0.575501  0.263551
# PAY_3    0.574245  0.766552  1.000000  0.777359  0.686775  0.632684  0.235253
# PAY_4    0.538841  0.662067  0.777359  1.000000  0.819835  0.716449  0.216614
# PAY_5    0.509426  0.622780  0.686775  0.819835  1.000000  0.816900  0.204149
# PAY_6    0.474553  0.575501  0.632684  0.716449  0.816900  1.000000  0.186866
# def_pay  0.324794  0.263551  0.235253  0.216614  0.204149  0.186866  1.000000

# %%
from patsy import dmatrices
y, X = dmatrices("def_pay ~ AGE + LIMIT_BAL + BILL_AMT1 + BILL_AMT2 + BILL_AMT3 + BILL_AMT4 + BILL_AMT5 + BILL_AMT6 + PAY_AMT1 + PAY_AMT2 + PAY_AMT3 + PAY_AMT4 + PAY_AMT5 + PAY_AMT6 + PAY_0 + PAY_5 + PAY_2 + PAY_3 + PAY_4 + PAY_6", df, return_type='dataframe')
#Step 2: Calculate VIF Factors
# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)
# Out:
#     VIF Factor   features
# 0         16.6  Intercept
# 1          1.0        AGE
# 2          1.5  LIMIT_BAL
# 3         14.0  BILL_AMT1
# 4         25.9  BILL_AMT2
# 5         21.8  BILL_AMT3
# 6         20.3  BILL_AMT4
# 7         25.0  BILL_AMT5
# 8         15.0  BILL_AMT6
# 9          1.7   PAY_AMT1
# 10         2.2   PAY_AMT2
# 11         1.8   PAY_AMT3
# 12         1.6   PAY_AMT4
# 13         1.7   PAY_AMT5
# 14         1.2   PAY_AMT6
# 15         1.9      PAY_0
# 16         4.7      PAY_5
# 17         3.2      PAY_2
# 18         3.7      PAY_3
# 19         4.3      PAY_4
# 20         3.3      PAY_6

# %%
df_corr = df.copy()
df_corr = df_corr.drop(['SEX'], axis = 1)
COR = df_corr.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(COR, square=True, annot=True, fmt = ".1f" , cmap="YlGnBu")
plt.savefig('heatmap.png')

# %% [markdown]
# # Categorical Attributes

# %%
sns.countplot(x='PAY_0', data=df,hue="def_pay", palette="rainbow")
plt.savefig('payanddef')

# %%
sns.countplot(x='SEX', data=df,hue="def_pay", palette="rainbow")

# %%
sns.countplot(x='def_pay', y = 'EDUCATION', data=df, palette = 'magma')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9bac696e7443> in <module>
# ----> 1 sns.countplot(x='def_pay', y = 'EDUCATION', data=df, palette = 'magma')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3544         y = x
#    3545     elif x is not None and y is not None:
# -> 3546         raise TypeError("Cannot pass values for both `x` and `y`")
#    3547     else:
#    3548         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
sns.countplot(x='PAY_2', data=df,hue="def_pay", palette="rainbow")

# %%
sns.countplot(x='PAY_3', data=df,hue="def_pay", palette="rainbow")

# %%
sns.countplot(x='PAY_4', data=df,hue="def_pay", palette="rainbow")

# %%
X = df.drop(['def_pay'],axis=1)
X.corrwith(df['def_pay']).plot.bar(figsize = (7, 7), title = "Correlation with Default", 
                                        fontsize = 9,rot = 90, grid = True)
plt.savefig('corrdef.png')

# %%
sns.boxplot(x='SEX', y='AGE', hue = 'def_pay', data=df, palette = 'magma')
plt.savefig('sexandage.png')

# %%
sns.boxplot(x='def_pay',y='LIMIT_BAL',data=df , palette = 'viridis')
plt.savefig('limitdef.png')

# %%
sns.distplot(df['AGE'], kde = True)

# %%
df['EDUCATION'] = df['EDUCATION'].replace({1:'graduate school', 2:'university', 3:'high school', 
                                           4:'others', 5:'unknown', 6:'unknown', 0:'unknown'})
#plt.subplot(1,3,2)
sns.countplot('EDUCATION', hue = 'def_pay', data=df , palette = 'viridis')
plt.savefig('educationpayment.png')

# %%
g = sns.FacetGrid(df, col='SEX', hue='def_pay')
g.map(plt.hist, 'AGE', alpha=0.6, bins=25) #alpha is for opacity
g.add_legend()

plt.savefig('sexandage.png')

# %%
g = sns.FacetGrid(df, col='SEX', hue='def_pay')
g.map(plt.hist, 'PAY_0', alpha=0.6, bins=25) #alpha is for opacity
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'def_pay'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-5b892daba029> in <module>
# ...

# %%
df = df.rename(columns={'PAY_0': 'PAY_1'})

def getColumnsNames(prefix):
    return [prefix+str(x) for x in range(1,7)]


# PAY_1 , PAY_2 , PAY_3 , PAY_4 , PAY_5, PAY_6
pay_status_columns = getColumnsNames('PAY_')
figure, ax = plt.subplots(2,3)
figure.set_size_inches(18,8)


for i in range(len(pay_status_columns)):
    row,col = int(i/3), i%3

    d  = df[pay_status_columns[i]].value_counts()
    x = df[pay_status_columns[i]][(df['def_pay']==1)].value_counts()
    ax[row,col].bar(d.index, d, align='center', color='purple')
    ax[row,col].bar(x.index, x, align='center', color='pink', alpha=0.7)
    ax[row,col].set_title(pay_status_columns[i])
   


    
plt.show()

# %%
categorical_vars = ['SEX']
df[categorical_vars] = df[categorical_vars].astype(str)
df = pd.get_dummies(df,columns=categorical_vars,drop_first=True)
df.head()
# Out:
#    LIMIT_BAL  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0    20000.0          2         1   24      2      2     -1     -1     -2
# 1   120000.0          2         2   26     -1      2      0      0      0
# 2    90000.0          2         2   34      0      0      0      0      0
# 3    50000.0          2         1   37      0      0      0      0      0
# 4    50000.0          2         1   57     -1      0     -1      0      0
#
#    PAY_6  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0     -2  ...        0.0        0.0       0.0     689.0       0.0       0.0
# 1      2  ...     3455.0     3261.0       0.0    1000.0    1000.0    1000.0
# 2      0  ...    14948.0    15549.0    1518.0    1500.0    1000.0    1000.0
# 3      0  ...    28959.0    29547.0    2000.0    2019.0    1200.0    1100.0
# 4      0  ...    19146.0    19131.0    2000.0   36681.0   10000.0    9000.0
#
#    PAY_AMT5  PAY_AMT6  def_pay  SEX_2
# ...

# %%
x = StandardScaler().fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
pca = PCA().fit(x)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %%
finalDf = pd.concat([principalDf, df[['def_pay']]], axis = 1)
finalDf.head()
# Out:
#    principal component 1  principal component 2  def_pay
# 0              -1.887963              -0.906100        1
# 1              -0.764696              -2.109292        1
# 2              -0.847408              -1.072179        0
# 3              -0.196589              -0.809022        0
# 4              -0.840934              -0.072535        0

# %%
from sklearn.model_selection import train_test_split
train_data = df.drop('def_pay', axis=1)
labels = df["def_pay"]
X_train, X_test, y_train, y_test = train_test_split( train_data , labels, test_size=0.20, random_state = 2)

# %%
select_feat = pd.DataFrame()
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C = 0.01, penalty = 'l2').fit(train_data,labels)
model = SelectFromModel(lsvc, prefit = True)
X_new = model.transform(train_data)

feature_idx = model.get_support()
feature_name = train_data.columns[feature_idx]

feature_name
# Out:
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Index(['AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6'], dtype='object')

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(train_data,labels)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.06498902 0.03401541 0.02363841 0.06599338 0.09768896 0.05734088
#  0.02624867 0.02812836 0.024955   0.03324218 0.04928402 0.04596084
#  0.04585535 0.04392021 0.0439518  0.04387541 0.04278003 0.04219969
#  0.04297525 0.04239106 0.0431284  0.04602878 0.01140889]

# %%
log_reg_pipe = Pipeline([('scaler', StandardScaler()), ('log_reg', LogisticRegression(solver = 'liblinear', penalty = 'l2' ))])
fit_lr = log_reg_pipe.fit(X_train, y_train)
cv_scores1 = cross_val_score(log_reg_pipe, X_train, y_train, cv = 5, scoring = 'f1')
print(cv_scores1.mean())
print(cv_scores1.std())
#pred_y_0 = fit_lr.predict(X_test)
# Out:
# 0.3512318793008413
# 0.012196601794915825

# %%
def plot_confusion_matrix(y_true, y_pred, classes=np.array([0.0,1.0]), normalize=False, title=None, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    tn = cm[0][0] 
    fp = cm[0][1] 
    fn = cm[1][0] 
    tp = cm[1][1]
    acc = (tp + tn) / (tp + fp + fn + tn)
    prec = tp / (tp + fp)
    recall = tp / (tp + fn) 
    spec = tn / ( tn + fp )
    #print(tp)
    print(f'Training accuracy, ', acc )
    print(f'Training precision, ', prec )
    print(f'Training recall, ', recall )
    print(f'Training specificity, ', spec)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots()
    ax.axis('equal')
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout();
    return ax



ypred = grid_rf.predict(X_val)
cm = plot_confusion_matrix(y_val,ypred,np.array([0,1]))
from sklearn.metrics import f1_score
f1_score(y_val, ypred) #class imbalance
# Out:
# Training accuracy,  0.7989333333333334
# Training precision,  0.7531645569620253
# Training recall,  0.14268585131894485
# Training specificity,  0.9866255144032922
# Confusion matrix, without normalization
# 0.2399193548387097

# %%
train_val = df.drop('def_pay', axis=1)
labels_val = df["def_pay"]

X_trainval, X_val, y_trainval, y_val = train_test_split(
    train_val, labels_val, test_size=0.25, random_state=1)

# %%
from sklearn.svm import SVC
from sklearn.metrics import recall_score, make_scorer, confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.preprocessing import StandardScaler, MinMaxScaler
linear_svc_pipe = Pipeline([
    ('scale', MinMaxScaler(feature_range=(-1,1))),
    ('MySVCLinear', LinearSVC(penalty='l2'))
])


param_grid_linsvm = {'MySVCLinear__C' : np.linspace(1e-2, 1, 2)}

grid_svmlin = GridSearchCV(linear_svc_pipe, param_grid_linsvm, cv=5, scoring = 'precision')
 
svc_gscv_lin = grid_svmlin.fit(X_train,y_train)
svc_gscv_lin.best_score_
#means = svc_gscv_lin.cv_results_['mean_test_score']
#stds = svc_gscv_lin.cv_results_['std_test_score']
svc_gscv_lin.cv_results_['std_test_score'][svc_gscv_lin.best_index_]
# Out:
# 0.049852446503726174

# %%
from sklearn.svm import SVC
from sklearn.metrics import recall_score, make_scorer, confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scale_svc_pipe = Pipeline([
    ('scale', MinMaxScaler(feature_range=(-1,1))),
    ('MySVC', SVC(kernel='rbf', gamma = 'auto', C = 1))
])


param_grid = {'MySVC__gamma' : np.linspace(1e-2, 100, 10), 'MySVC__kernel' : ['rbf'], 'MySVC__C' : np.linspace(1e-2, 1, 10)}

grid = GridSearchCV(scale_svc_pipe, param_grid, cv=5, scoring = 'precision')
 
svc_gscv = grid.fit(X_train,y_train)

svc_gscv.best_score_
# Out:
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf_pipe = Pipeline([('random_forest' , RandomForestClassifier(n_estimators=500, max_depth=3, random_state=0))])
#cv_scores_rf = cross_val_score(rf_pipe, X_train, y_train, cv = 5, scoring = make_scorer(mean_squared_error))
rf_pipe.get_params().keys()

param_grid_rf = {'random_forest__n_estimators' : [100,200,300,400,500], 'random_forest__max_depth' : [1,2,3,4,5]}
grid_rf = GridSearchCV(rf_pipe, param_grid_rf, cv=5, scoring = 'f1')

fit_rf = grid_rf.fit(X_train, y_train)

fit_rf.best_score_
# Out:
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\simra\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
print(fit_rf.best_estimator_)
# Out:
# Pipeline(memory=None,
#          steps=[('random_forest',
#                  RandomForestClassifier(bootstrap=True, class_weight=None,
#                                         criterion='gini', max_depth=2,
#                                         max_features='auto',
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=0,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
from sklearn.neighbors import KNeighborsClassifier


knn_pipe = Pipeline([('knn' ,KNeighborsClassifier())])
#classifier = KNeighborsClassifier(n_neighbors=5)
#classifier.fit(X_train, y_train)
param_grid_knn = {'knn__n_neighbors' : [3,5,7,9]}
grid_knn = GridSearchCV(knn_pipe, param_grid_knn, cv=5, scoring = 'precision')

fit_knn = grid_knn.fit(X_train, y_train)

fit_knn.best_score_

fit_knn.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('knn',
#                  KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                       metric='minkowski', metric_params=None,
#                                       n_jobs=None, n_neighbors=9, p=2,
#                                       weights='uniform'))],
#          verbose=False)

# %%
from sklearn import ensemble

xgboost_pipe = Pipeline([('xgboost', ensemble.GradientBoostingClassifier())])

param_grid_xg = { 'xgboost__max_depth' : [1,2,3,4,5], 'xgboost__n_estimators' : [100,200,300,400,500]}
grid_xg = GridSearchCV(xgboost_pipe, param_grid_xg, cv=5, scoring = 'precision')

fit_xg = grid_xg.fit(X_train, y_train)

fit_xg.best_score_
# Out:
# 0.6878266440401916

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['def_pay'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
plt.savefig('pcanotsampled.png')

# %%
pca.explained_variance_ratio_
# Out:
# array([0.28448215, 0.17818817])

# %%
from sklearn.model_selection import train_test_split
train_data = df.drop('def_pay', axis=1)
labels = df["def_pay"]
X_train, X_test, y_train, y_test = train_test_split( train_data , labels, test_size=0.20, random_state = 2)

# %%
log_reg_pipe = Pipeline([('scaler', StandardScaler()), ('log_reg', LogisticRegression(solver = 'liblinear', penalty = 'l2'))])

# %%
fit_lr = log_reg_pipe.fit(X_train, y_train)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
cv_scores1 = cross_val_score(log_reg_pipe, X_train, y_train, cv = 5, scoring = make_scorer(mean_squared_error))

# %%
cv_scores1.mean()
# Out:
# 0.20058371009658754

# %%
import statsmodels.api as sm

model = sm.OLS(y_train,X_train)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                def_pay   R-squared (uncentered):                   0.309
# Model:                            OLS   Adj. R-squared (uncentered):              0.308
# Method:                 Least Squares   F-statistic:                              466.0
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):                        0.00
# Time:                        15:22:00   Log-Likelihood:                         -11499.
# No. Observations:               24000   AIC:                                  2.304e+04
# Df Residuals:                   23977   BIC:                                  2.323e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                def_pay   R-squared (uncentered):                   0.308
# Model:                            OLS   Adj. R-squared (uncentered):              0.308
# Method:                 Least Squares   F-statistic:                              593.2
# Date:                Sun, 01 Dec 2019   Prob (F-statistic):                        0.00
# Time:                        15:20:39   Log-Likelihood:                         -11513.
# No. Observations:               24000   AIC:                                  2.306e+04
# Df Residuals:                   23982   BIC:                                  2.321e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
